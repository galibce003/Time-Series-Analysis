# %% [markdown]
# ## **Importing necessary modules**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import r2_score

from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# %% [markdown]
# <br/>
#
# ## **Connected with google drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# <br/>
#
# ## **Getting the data**
# We are using **Google stock price** dataset.
# Source: [Kaggle]('https://www.kaggle.com/')

# %%
df = pd.read_csv('drive/My Drive/Datasets/Google_Stock_Price_Train.csv')
test_df = pd.read_csv('drive/My Drive/Datasets/Google_Stock_Price_Test.csv')

# %% [markdown]
# <br/>
#
# ## **Reconnaissance**

# %%
df.head()
# Out:
#         Date    Open    High     Low   Close   Volume
# 0  26-Sep-17  936.69  944.08  935.12  937.43  1672749
# 1  25-Sep-17  939.45  939.75  924.51  934.28  1873375
# 2  22-Sep-17  942.77  950.00  940.84  943.26  1074806
# 3  21-Sep-17  948.13  952.80  939.38  947.55  1370685
# 4  20-Sep-17  937.73  950.00  937.50  947.54  2004018

# %%
test_df.head()
# Out:
#         Date     Open     High      Low    Close   Volume
# 0  25-Oct-17   986.27   994.43   977.72   991.46  1395282
# 1  24-Oct-17   986.50   989.26   977.08   988.49  1445129
# 2  23-Oct-17  1005.18  1005.79   983.10   985.54  1639294
# 3  20-Oct-17  1007.05  1008.65  1002.27  1005.07  1606031
# 4  19-Oct-17  1004.75  1007.32   997.30  1001.84  1714243

# %%
df.shape
# Out:
# (1258, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   float64
#  5   Volume  1258 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 59.1+ KB

# %% [markdown]
# <br/>
#
# # **Feature Engineering**
#
# <br/>
# <br/>
#
# ## **Converting the data type of 'Data' into datetime object**

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume             int64
# dtype: object

# %% [markdown]
# <br/>
#
# ## **Ordering the 'Date' feature**

# %%
df = df.sort_values(by = ['Date'], ascending = True).reset_index()

# %%
df.head()
# Out:
#    index       Date    Open    High     Low   Close   Volume
# 0   1257 2012-09-26  375.30  381.00  370.87  377.11  5674334
# 1   1256 2012-09-27  380.35  381.80  376.20  378.63  3932272
# 2   1255 2012-09-28  377.45  380.03  375.95  377.63  2784091
# 3   1254 2012-10-01  379.90  382.88  378.48  381.27  3168477
# 4   1253 2012-10-02  382.98  383.38  375.51  378.87  2790375

# %%
df.tail()
# Out:
#       index       Date    Open    High     Low   Close   Volume
# 1253      4 2017-09-20  937.73  950.00  937.50  947.54  2004018
# 1254      3 2017-09-21  948.13  952.80  939.38  947.55  1370685
# 1255      2 2017-09-22  942.77  950.00  940.84  943.26  1074806
# 1256      1 2017-09-25  939.45  939.75  924.51  934.28  1873375
# 1257      0 2017-09-26  936.69  944.08  935.12  937.43  1672749

# %% [markdown]
# <br/>
# <br/>
#
# # **Visualization**

# %%
plt.figure(figsize= (12, 5))
df['Open'].plot(color = 'red')
plt.show()

# %%
plt.figure(figsize= (12, 5))
df['Close'].plot(color = 'green')
plt.show()

# %%
plt.figure(figsize= (12, 5))
df['Volume'].plot(color = 'blue')
plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Feature Selection**

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
input_feature = df[['Open', 'High', 'Low', 'Volume', 'Close']]
input_data = input_feature.values

# %%
input_data[:5]
# Out:
# array([[3.753000e+02, 3.810000e+02, 3.708700e+02, 5.674334e+06,
#         3.771100e+02],
#        [3.803500e+02, 3.818000e+02, 3.762000e+02, 3.932272e+06,
#         3.786300e+02],
#        [3.774500e+02, 3.800300e+02, 3.759500e+02, 2.784091e+06,
#         3.776300e+02],
#        [3.799000e+02, 3.828800e+02, 3.784800e+02, 3.168477e+06,
#         3.812700e+02],
#        [3.829800e+02, 3.833800e+02, 3.755100e+02, 2.790375e+06,
#         3.788700e+02]])

# %% [markdown]
# <br/>
# <br/>
#
# ## **Feature Scaling**

# %%
scaler = MinMaxScaler(feature_range= (0, 1))
input_data[:, :] = scaler.fit_transform(input_data[:, :])

# %%
input_data[:5]
# Out:
# array([[0.07619802, 0.07945378, 0.07747309, 0.41770245, 0.07819275],
#        [0.08360086, 0.08062718, 0.08533097, 0.2764961 , 0.08042683],
#        [0.07934972, 0.07803104, 0.08496241, 0.18342797, 0.07895704],
#        [0.0829412 , 0.08221127, 0.08869232, 0.21458516, 0.08430707],
#        [0.08745621, 0.08294464, 0.08431373, 0.18393734, 0.08077958]])

# %%
len(df)
# Out:
# 1258

# %%
lookback=50
total_size = len(df)

X=[]
y=[]

for i in range(0, total_size-lookback):
    t = []
    
    for j in range(0, lookback): # loop for 50 days
        current_index = i+j
        t.append(input_data[current_index, :]) # get data margin from 50 days with marging i
    X.append(t)
    y.append(input_data[lookback+i, 4])

# %%
X[0]
# Out:
# [array([0.07619802, 0.07945378, 0.07747309, 0.41770245, 0.07819275]),
#  array([0.08360086, 0.08062718, 0.08533097, 0.2764961 , 0.08042683]),
#  array([0.07934972, 0.07803104, 0.08496241, 0.18342797, 0.07895704]),
#  array([0.0829412 , 0.08221127, 0.08869232, 0.21458516, 0.08430707]),
#  array([0.08745621, 0.08294464, 0.08431373, 0.18393734, 0.08077958]),
#  array([0.08050779, 0.08141923, 0.08574377, 0.13678355, 0.08483619]),
#  array([0.0856678 , 0.08580481, 0.09105116, 0.15671199, 0.0889222 ]),
#  array([0.09150212, 0.08910499, 0.09517912, 0.17967179, 0.08862825]),
#  array([0.08437779, 0.08116988, 0.08717382, 0.11651816, 0.08141158]),
#  array([0.08341029, 0.07951245, 0.07860829, 0.20124374, 0.07129944]),
#  array([0.07033437, 0.06939189, 0.07546808, 0.12321169, 0.07163749]),
#  array([0.07844086, 0.07744434, 0.08432847, 0.15099674, 0.07673766]),
#  array([0.07766393, 0.07477485, 0.07975822, 0.15284484, 0.07178447]),
#  array([0.07039301, 0.0666784 , 0.06988058, 0.202558  , 0.06900657]),
#  array([0.06907369, 0.06899586, 0.07412649, 0.12461114, 0.07174038]),
#  array([0.07187358, 0.07586025, 0.07692761, 0.14360693, 0.07967723]),
#  array([0.08037586, 0.07811904, 0.02951496, 0.9662973 , 0.03518674]),
#  array([0.04371344, 0.03941154, 0.02656642, 0.88857027, 0.02547143]),
#  array([0.02569741, 0.02321863, 0.02485626, 0.28667686, 0.02316387]),
#  array([0.01908615, 0.02519874, 0.02656642, 0.1941994 , 0.02441319]),
#  array([0.02993389, 0.0249494 , 0.02896948, 0.16010949, 0.02216441]),
#  array([0.02494979, 0.02128253, 0.02767212, 0.15259429, 0.02250246]),
#  array([0.02238445, 0.02204523, 0.02597671, 0.11588916, 0.02057704]),
#  array([0.02484718, 0.02054915, 0.02877783, 0.08234258, 0.02436909]),
#  array([0.02458332, 0.02782422, 0.03151998, 0.12396293, 0.02973382]),
#  array([0.03579753, 0.03122708, 0.03790358, 0.14618049, 0.02996899]),
#  array([0.02824809, 0.02484672, 0.02919062, 0.09035855, 0.02632391]),
#  array([0.02896639, 0.02458271, 0.03065015, 0.08606593, 0.02541264]),
#  array([0.02128502, 0.01852504, 0.02249742, 0.13871263, 0.01466849]),
#  array([0.01776683, 0.01356743, 0.01123397, 0.16839879, 0.00376266]),
#  array([0.00634739, 0.01124996, 0.0105558 , 0.21017622, 0.01167012]),
#  array([0.01303194, 0.01232069, 0.01835471, 0.07171349, 0.01377192]),
#  array([0.0124749 , 0.01070727, 0.01639393, 0.08701454, 0.00874524]),
#  array([0.01075978, 0.00673238, 0.01070323, 0.09298707, 0.00395373]),
#  array([2.93182051e-03, 5.13362082e-03, 5.82338198e-03, 1.07627344e-01,
#         5.87915399e-05]),
#  array([0.        , 0.        , 0.        , 0.23647241, 0.        ]),
#  array([0.00712432, 0.01167532, 0.01440366, 0.14983997, 0.01547687]),
#  array([0.01725376, 0.01834903, 0.02108212, 0.12709294, 0.01677029]),
#  array([0.01687263, 0.01232069, 0.01800088, 0.12903223, 0.01375722]),
#  array([0.01759092, 0.01246736, 0.02220257, 0.0325311 , 0.0153005 ]),
#  array([0.01499626, 0.01026724, 0.01698364, 0.1365313 , 0.01028852]),
#  array([0.01040796, 0.0161489 , 0.01623176, 0.16117839, 0.01731411]),
#  array([0.01615433, 0.02342398, 0.02058086, 0.20432844, 0.02685304]),
#  array([0.03065218, 0.03002435, 0.03393779, 0.18314046, 0.03289387]),
#  array([0.03324684, 0.0339259 , 0.03666519, 0.21425801, 0.03765598]),
#  array([0.04126537, 0.03882484, 0.04287189, 0.13559274, 0.03536311]),
#  array([0.03595878, 0.03119775, 0.03666519, 0.11919142, 0.03226186]),
#  array([0.03386253, 0.03046437, 0.03418841, 0.10874561, 0.0298955 ]),
#  array([0.03052025, 0.03127108, 0.03579537, 0.07628073, 0.03233535]),
#  array([0.03595878, 0.0322098 , 0.03424738, 0.11334486, 0.02724988])]

# %%
y[0]
# Out:
# 0.028131751840910046

# %% [markdown]
# <br/>
# <br/>
#
# ## **Splitting into Train, Test and Validation set**

# %%
test_size = 100
validate_size = 10

X, y = np.array(X), np.array(y)


X_test = X[test_size:]
y_test = y[test_size:]


X_work = X[:test_size]
y_work = y[:test_size]


X_valid = X[:validate_size]
y_valid = y[:validate_size]
X_train = X[validate_size:]
y_train = y[validate_size:]

# %% [markdown]
# <br/>
#
# #### **Shape of the Train, Test and Validation set**

# %%
print('Shape of X_Train set : {}'.format(X_train.shape))
print('Shape of y_Train set : {}'.format(y_train.shape))
print('Shape of X_test set : {}'.format(X_test.shape))
print('Shape of y_test set : {}'.format(y_test.shape))
print('Shape of X_valid set : {}'.format(X_valid.shape))
print('Shape of y_valid set : {}'.format(y_valid.shape))
print('Shape of X_work set : {}'.format(X_work.shape))
print('Shape of y_work set : {}'.format(y_work.shape))
# Out:
# Shape of X_Train set : (1198, 50, 5)
# Shape of y_Train set : (1198,)
# Shape of X_test set : (1108, 50, 5)
# Shape of y_test set : (1108,)
# Shape of X_valid set : (10, 50, 5)
# Shape of y_valid set : (10,)
# Shape of X_work set : (100, 50, 5)
# Shape of y_work set : (100,)

# %% [markdown]
# <br/>
#
# ## **Reshaping**

# %%
X_train = X_train.reshape(X_train.shape[0], lookback, 5)
X_test = X_test.reshape(X_test.shape[0], lookback, 5)
X_valid = X_valid.reshape(X_valid.shape[0], lookback, 5)

print(X_train.shape)
print(X_valid.shape)
print(X_test.shape)
# Out:
# (1198, 50, 5)
# (10, 50, 5)
# (1108, 50, 5)

# %% [markdown]
# <br/>
#
# ## **RNN (LSTM) model architecture**

# %%
model = Sequential()

model.add(LSTM(50, return_sequences= True, activation = 'relu', input_shape = (X.shape[1], 5)))
model.add(LSTM(50, return_sequences= True, activation = 'relu'))
model.add(LSTM(50))

model.add(Dense(1, activation='linear'))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %% [markdown]
# <br/>
#
# #### **Model Summary**

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 50)            11200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 50)            20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 51,651
# Trainable params: 51,651
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# <br/>
#
# ## **Callbacks**

# %%
callbacks = [EarlyStopping(patience = 10, verbose = 1),
             ReduceLROnPlateau(factor = 0.1, patience = 3, min_lr = 0.00001, verbose = 1),
             ModelCheckpoint('model.h5', verbose = 1, save_best_only = True, save_weights_only= True)]

# %% [markdown]
# <br/>
#
# ## **Compile the model**

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['accuracy'])

# %% [markdown]
# <br/>
#
# ## **Train the model**

# %%
history = model.fit(X_train, y_train, epochs = 100, batch_size = 32, validation_data = (X_valid, y_valid), callbacks = callbacks)
# Out:
# Epoch 1/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0415 - accuracy: 8.3472e-04
# Epoch 00001: val_loss improved from inf to 0.00635, saving model to model.h5
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0415 - accuracy: 8.3472e-04 - val_loss: 0.0063 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 8.3472e-04
# Epoch 00002: val_loss improved from 0.00635 to 0.00038, saving model to model.h5
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0015 - accuracy: 8.3472e-04 - val_loss: 3.7981e-04 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 8.3472e-04
# Epoch 00003: val_loss improved from 0.00038 to 0.00013, saving model to model.h5
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0012 - accuracy: 8.3472e-04 - val_loss: 1.3440e-04 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 8.3472e-04
# Epoch 00004: val_loss improved from 0.00013 to 0.00007, saving model to model.h5
# 38/38 [==============================] - 5s 142ms/step - loss: 0.0012 - accuracy: 8.3472e-04 - val_loss: 6.5792e-05 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 8.3472e-04
# Epoch 00005: val_loss improved from 0.00007 to 0.00006, saving model to model.h5
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0011 - accuracy: 8.3472e-04 - val_loss: 6.0260e-05 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 8.3472e-04
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00006: val_loss did not improve from 0.00006
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0011 - accuracy: 8.3472e-04 - val_loss: 6.4138e-05 - val_accuracy: 0.0000e+00
# Epoch 7/100
# 38/38 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 8.3472e-04
# Epoch 00007: val_loss did not improve from 0.00006
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0010 - accuracy: 8.3472e-04 - val_loss: 6.9464e-05 - val_accuracy: 0.0000e+00
# Epoch 8/100
# 38/38 [==============================] - ETA: 0s - loss: 9.8777e-04 - accuracy: 8.3472e-04
# Epoch 00008: val_loss improved from 0.00006 to 0.00006, saving model to model.h5
# 38/38 [==============================] - 6s 147ms/step - loss: 9.8777e-04 - accuracy: 8.3472e-04 - val_loss: 5.5451e-05 - val_accuracy: 0.0000e+00
# Epoch 9/100
# 38/38 [==============================] - ETA: 0s - loss: 9.8489e-04 - accuracy: 8.3472e-04
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00009: val_loss improved from 0.00006 to 0.00005, saving model to model.h5
# 38/38 [==============================] - 5s 143ms/step - loss: 9.8489e-04 - accuracy: 8.3472e-04 - val_loss: 5.1905e-05 - val_accuracy: 0.0000e+00
# Epoch 10/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7512e-04 - accuracy: 8.3472e-04
# Epoch 00010: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 146ms/step - loss: 9.7512e-04 - accuracy: 8.3472e-04 - val_loss: 5.2362e-05 - val_accuracy: 0.0000e+00
# Epoch 11/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7319e-04 - accuracy: 8.3472e-04
# Epoch 00011: val_loss did not improve from 0.00005
# 38/38 [==============================] - 5s 145ms/step - loss: 9.7319e-04 - accuracy: 8.3472e-04 - val_loss: 5.2386e-05 - val_accuracy: 0.0000e+00
# Epoch 12/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7417e-04 - accuracy: 8.3472e-04
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1e-05.
#
# Epoch 00012: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 145ms/step - loss: 9.7417e-04 - accuracy: 8.3472e-04 - val_loss: 5.2748e-05 - val_accuracy: 0.0000e+00
# Epoch 13/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7231e-04 - accuracy: 8.3472e-04
# Epoch 00013: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 145ms/step - loss: 9.7231e-04 - accuracy: 8.3472e-04 - val_loss: 5.2657e-05 - val_accuracy: 0.0000e+00
# Epoch 14/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7104e-04 - accuracy: 8.3472e-04
# Epoch 00014: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 147ms/step - loss: 9.7104e-04 - accuracy: 8.3472e-04 - val_loss: 5.3349e-05 - val_accuracy: 0.0000e+00
# Epoch 15/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7096e-04 - accuracy: 8.3472e-04
# Epoch 00015: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 146ms/step - loss: 9.7096e-04 - accuracy: 8.3472e-04 - val_loss: 5.3204e-05 - val_accuracy: 0.0000e+00
# Epoch 16/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7061e-04 - accuracy: 8.3472e-04
# Epoch 00016: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 146ms/step - loss: 9.7061e-04 - accuracy: 8.3472e-04 - val_loss: 5.2965e-05 - val_accuracy: 0.0000e+00
# Epoch 17/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7176e-04 - accuracy: 8.3472e-04
# Epoch 00017: val_loss did not improve from 0.00005
# 38/38 [==============================] - 5s 144ms/step - loss: 9.7176e-04 - accuracy: 8.3472e-04 - val_loss: 5.4158e-05 - val_accuracy: 0.0000e+00
# Epoch 18/100
# 38/38 [==============================] - ETA: 0s - loss: 9.7008e-04 - accuracy: 8.3472e-04
# Epoch 00018: val_loss did not improve from 0.00005
# 38/38 [==============================] - 6s 146ms/step - loss: 9.7008e-04 - accuracy: 8.3472e-04 - val_loss: 5.3788e-05 - val_accuracy: 0.0000e+00
# Epoch 19/100
# 38/38 [==============================] - ETA: 0s - loss: 9.6930e-04 - accuracy: 8.3472e-04
# Epoch 00019: val_loss did not improve from 0.00005
# 38/38 [==============================] - 5s 143ms/step - loss: 9.6930e-04 - accuracy: 8.3472e-04 - val_loss: 5.4016e-05 - val_accuracy: 0.0000e+00
# Epoch 00019: early stopping

# %% [markdown]
# <br/>
#
# ## **Loss vs Epochs**

# %%
plt.plot(history.history['loss'])
plt.show()

# %% [markdown]
# <br/>
#
# ## **Prediction**

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# <br/>
#
# ## **Visualize the model with the actual and predicted values**

# %%
plt.figure(figsize = (12, 5))

plt.plot(y_test, color = 'green', label = 'Actual')
plt.plot(y_pred, color = 'red', label = 'Predicted')

plt.show()

# %% [markdown]
# <br/>
#
# ## **Creating a pandas DataFrame with the actual and predicted values**

# %%
df_result = pd.DataFrame(np.c_[y_test, y_pred], columns = ['Actual', 'Predicted'])
df_result
# Out:
#         Actual  Predicted
# 0     0.157708   0.127594
# 1     0.154519   0.129682
# 2     0.166586   0.132165
# 3     0.165013   0.135047
# 4     0.171451   0.138287
# ...        ...        ...
# 1103  0.916604   0.917381
# 1104  0.916619   0.916991
# 1105  0.910314   0.916647
# 1106  0.897115   0.916401
# 1107  0.901745   0.916012
#
# [1108 rows x 2 columns]

# %% [markdown]
# <br/>
#
# ## **Accuracy Score**

# %%
print('Accuracy Score is {}%'.format(r2_score(y_test, y_pred).round(4)*100))
# Out:
# Accuracy Score is 97.97%
